# %%
import sys
sys.path.append("..")

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from data_tools.get_dataset import *

# %%
datasets_used = ["plasticc", "kMNIST28", "pennylane_hidden-manifold"]
for ds_string in datasets_used:
    x_train, x_test, y_train, y_test = load_dataset(ds_string, 2, 400, 0.8, 1) 
    #plot x_train_pure[:,0], x_train_pure[:,1], and use y for color
    plt.title(ds_string)
    plt.scatter(x_train[:,0], x_train[:,1], c=y_train, cmap='viridis')
    plt.show()
# Out:
# Loading dataset: plasticc
# plasticc_2qubits_400points_0.8train_test_1seed
# Using plasticc_2qubits_400points_0.8train_test_1seed seed 1
# Loading dataset: kMNIST28
# kMNIST28_2qubits_400points_0.8train_test_1seed
# Using kMNIST28_2qubits_400points_0.8train_test_1seed seed 1
# Loading dataset: pennylane_hidden-manifold
# pennylane_hidden-manifold_2qubits_400points_0.8train_test_1seed
# Using pennylane_hidden-manifold_2qubits_400points_0.8train_test_1seed seed 1

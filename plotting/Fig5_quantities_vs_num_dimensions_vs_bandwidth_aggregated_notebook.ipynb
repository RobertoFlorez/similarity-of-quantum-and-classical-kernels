# %%
from quantities_vs_num_dimensions_vs_bandwidth import *
import os 



simulation_set_index_kMNIST = [[(0, 5), (0, 7), (0, 8), (0, 27), (0, 31), (0, 13), (0, 15), (0, 16), (0, 28), (0, 33)], "kMNIST28"]
simulation_set_index_pennylane = [[(0, 55), (0, 60), (0, 56), (0, 61), (0, 57), (0, 62), (0, 59), (0, 64), (0, 58), (0, 63)], "hidden-manifold"]
simulation_set_index_plasticc = [[(0, 3), (0, 4), (0, 25), (0, 30), (0, 9), (0, 11), (0, 12), (0, 26), (0, 32)], "plasticc"]


simulation_sets = [ simulation_set_index_plasticc ] # rerun with the other simulation sets to obtain the plots
for simulation_set in simulation_sets:
    dataset_name = simulation_set[1]
    QK_str = "num"

    kernel_to_compare = ["rbf_poly_2", "rbf"]


    path_to_save = f"../data/plots/{dataset_name}_{QK_str}_numdimensions/"

    df_concat = pd.DataFrame()  
    for pair_index in simulation_set[0]:
        simulation_set_index = pair_index[0]
        dataset_set_index = pair_index[1]

        pd_geo_gramm_performance_both_ds1, pd_geo_top_results_enc_ds1, values_of_best_quantum_ds1, values_of_best_poly_ds1, N_train_ds1, dataset_name_str_ds1, encoding_circuit_name_str_ds1, kernel_type_to_keep_ds1, path_to_save_ds1 = load_and_return_preprocessed(simulation_set_index, dataset_set_index, dataset_name, kernel_to_compare, add_extra_path=True)

        melted_ds_i, kernel_type_to_keep_du, num_qubit_order = top_enc_melting_preprocess(pd_geo_top_results_enc_ds1, kernel_type_to_keep_ds1, encoding_circuit_name_str_ds1, kernel_to_compare, [kernel_type_str, num_qubit_str, performance_str, top_eigenvalue_str, frobenius_str, g_str, bandwidth_str, varK_str], use_kernel_acronym=True)

        df_concat = pd.concat([df_concat, melted_ds_i])
# Out:
# Simulation set index: 0 and dataset set index: 3
# 184.3214807510376
# 7.690129280090332
# Index(['dataset_name', 'num_qubits', 'C_poly', 'bandwidth',
#        'roc_auc_score_poly', 'y_pred_poly', 'y_pred_train_poly',
#        'varK_train_poly', 'd_poly', 'K_max_eig_poly', 'd_poly',
#        'roc_auc_score_train_poly', 'eigenvalues_poly', 'kernel', 'seed',
#        'ck_poly', 'K_mean_train', 'num_datapoints', 'C_quantum',
#        'roc_auc_score_quantum', 'y_pred_quantum', 'y_pred_train_quantum',
#        'varK_train_quantum', 'd_quantum', 'K_max_eig_quantum', 'varK_test',
#        'roc_auc_score_train_quantum', 'eigenvalues_quantum',
#        'encoding_circuit_name', 'ck_quantum', 'method', 'classical_kernel',
#        'quantum_kernel_name', 'degree', 'gamma', 'roc_auc_score_poly_extra',
#        'K_max_eig_poly_extra', 'eigenvalues', 'ck', 'num_layers',
#        'roc_auc_score_quantum_extra', 'K_max_eig_quantum_extra',
#        'Frobenius Difference', '$d_G$', '$d_Gmod$', 'g_gen_train',
#        'g_tra_train'],
#       dtype='object')
# classification_problem True
# Simulation set index: 0 and dataset set index: 4
# 208.01588249206543
# 7.331567287445068
# Index(['dataset_name', 'num_qubits', 'C_poly', 'bandwidth',
#        'roc_auc_score_poly', 'y_pred_poly', 'y_pred_train_poly',
#        'varK_train_poly', 'd_poly', 'K_max_eig_poly', 'd_poly',
#        'roc_auc_score_train_poly', 'eigenvalues_poly', 'kernel', 'seed',
#        'ck_poly', 'K_mean_train', 'num_datapoints', 'C_quantum',
#        'roc_auc_score_quantum', 'y_pred_quantum', 'y_pred_train_quantum',
#        'varK_train_quantum', 'd_quantum', 'K_max_eig_quantum', 'varK_test',
#        'roc_auc_score_train_quantum', 'eigenvalues_quantum',
#        'encoding_circuit_name', 'ck_quantum', 'method', 'classical_kernel',
#        'quantum_kernel_name', 'degree', 'gamma', 'roc_auc_score_poly_extra',
#        'K_max_eig_poly_extra', 'eigenvalues', 'ck', 'num_layers',
#        'roc_auc_score_quantum_extra', 'K_max_eig_quantum_extra',
#        'Frobenius Difference', '$d_G$', '$d_Gmod$', 'g_gen_train',
#        'g_tra_train'],
#       dtype='object')
# classification_problem True
# Simulation set index: 0 and dataset set index: 26
# 191.90257358551025
# 7.281665802001953
# keys OF FQKs
# Index(['K_test', 'K_train', 'bandwidth', 'ck', 'dataset_name', 'eigenvalues',
#        'eigenvectors', 'encoding_circuit_name', 'executor_type', 'method',
#        'num_datapoints', 'num_layers', 'num_qubits', 'seed',
#        'train_test_split_value', 'varK_test', 'varK_train'],
#       dtype='object')
# keys OF PQKs
# Index(['K_test', 'K_train', 'bandwidth', 'ck', 'dataset_name', 'eigenvalues',
#        'eigenvectors', 'encoding_circuit_name', 'executor_type',
#        'gamma_original', 'method', 'num_datapoints', 'num_layers',
#        'num_qubits', 'seed', 'train_test_split_value', 'varK_test',
#        'varK_train', 'expressivity'],
#       dtype='object')
# -+++++++++++++++++++++++++++++++
# HEAD OF FQKs
#    num_qubits  seed  bandwidth dataset_name  num_layers
# 0           2     1   0.001000     plasticc           2
# 1           2     1   0.001304     plasticc           2
# 2           2     1   0.001701     plasticc           2
# 3           2     1   0.002219     plasticc           2
# 4           2     1   0.002894     plasticc           2
# HEAD OF PQKs
#    num_qubits  seed  bandwidth dataset_name  num_layers
# 0           2     1   0.001000     plasticc           2
# 1           2     1   0.001304     plasticc           2
# 2           2     1   0.001701     plasticc           2
# 3           2     1   0.002219     plasticc           2
# 4           2     1   0.002894     plasticc           2
# Index(['dataset_name', 'num_qubits', 'C_poly', 'bandwidth',
#        'roc_auc_score_poly', 'y_pred_poly', 'y_pred_train_poly',
#        'varK_train_poly', 'd_poly', 'K_max_eig_poly', 'd_poly',
#        'roc_auc_score_train_poly', 'eigenvalues_poly', 'kernel', 'seed',
#        'ck_poly', 'K_mean_train', 'num_datapoints', 'C_quantum',
#        'roc_auc_score_quantum', 'y_pred_quantum', 'y_pred_train_quantum',
#        'varK_train_quantum', 'd_quantum', 'K_max_eig_quantum', 'varK_test',
#        'roc_auc_score_train_quantum', 'eigenvalues_quantum',
#        'encoding_circuit_name', 'ck_quantum', 'method', 'classical_kernel',
#        'quantum_kernel_name', 'degree', 'gamma', 'roc_auc_score_poly_extra',
#        'K_max_eig_poly_extra', 'eigenvalues', 'ck', 'num_layers',
#        'roc_auc_score_quantum_extra', 'K_max_eig_quantum_extra',
#        'Frobenius Difference', '$d_G$', '$d_Gmod$', 'g_gen_train',
#        'g_tra_train'],
#       dtype='object')
# classification_problem True

# %%
plot_metric_numdimension_normal(df_concat, "km", dataset_name_str_ds1, "h", N_train_ds1, kernel_to_compare, hide_xlabels=False, show_plt=False, show_abc=True)
# Out:
# c:\Users\jsl-rf\Desktop\WinterKernels_debug_organizing_repo\WinterKernels\plotting\quantities_vs_num_dimensions_vs_bandwidth.py:879: UserWarning: The palette list has more values (10) than needed (4), which may not be intended.
#   sns.boxplot(
# c:\Users\jsl-rf\Desktop\WinterKernels_debug_organizing_repo\WinterKernels\plotting\quantities_vs_num_dimensions_vs_bandwidth.py:879: UserWarning: The palette list has more values (10) than needed (4), which may not be intended.
#   sns.boxplot(
# showing abc
# showing abc
# c:\Users\jsl-rf\Desktop\WinterKernels_debug_organizing_repo\WinterKernels\plotting\quantities_vs_num_dimensions_vs_bandwidth.py:879: UserWarning: The palette list has more values (10) than needed (4), which may not be intended.
#   sns.boxplot(
# c:\Users\jsl-rf\Desktop\WinterKernels_debug_organizing_repo\WinterKernels\plotting\quantities_vs_num_dimensions_vs_bandwidth.py:859: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melted_copy_[combined_str] = melted_copy_.apply(lambda x: get_combined_latex_str(x), axis=1)
# showing abc
# showing abc
# c:\Users\jsl-rf\Desktop\WinterKernels_debug_organizing_repo\WinterKernels\plotting\quantities_vs_num_dimensions_vs_bandwidth.py:859: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melted_copy_[combined_str] = melted_copy_.apply(lambda x: get_combined_latex_str(x), axis=1)
# showing abc
